# %% [markdown]
# # Exploratory Analysis with Linear Regressions

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
admission_predict = pd.read_csv('./admission_predict.csv')
admission_predict.sort_values('Chance of Admit ', ascending=False)
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 202         203        340          120                  5  4.5   4.5  9.91
# 143         144        340          120                  4  4.5   4.0  9.92
# 24           25        336          119                  5  4.0   3.5  9.80
# 203         204        334          120                  5  4.0   5.0  9.87
# 71           72        336          112                  5  5.0   5.0  9.76
# ..          ...        ...          ...                ...  ...   ...   ...
# 457         458        295           99                  1  2.0   1.5  7.57
# 94           95        303           99                  3  2.0   2.5  7.66
# 58           59        300           99                  1  3.0   2.0  6.80
# 92           93        298           98                  2  4.0   3.0  8.03
# 376         377        297           96                  2  2.5   2.0  7.43
#
#      Research  Chance of Admit
# ...

# %%
admission_predict.head(5)
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Chance of Admit
# 0         1              0.92
# 1         1              0.76
# 2         1              0.72
# 3         1              0.80
# 4         0              0.65

# %%
admission_predict.describe()
# Out:
#        Serial No.   GRE Score  TOEFL Score  University Rating         SOP  \
# count  500.000000  500.000000   500.000000         500.000000  500.000000
# mean   250.500000  316.472000   107.192000           3.114000    3.374000
# std    144.481833   11.295148     6.081868           1.143512    0.991004
# min      1.000000  290.000000    92.000000           1.000000    1.000000
# 25%    125.750000  308.000000   103.000000           2.000000    2.500000
# 50%    250.500000  317.000000   107.000000           3.000000    3.500000
# 75%    375.250000  325.000000   112.000000           4.000000    4.000000
# max    500.000000  340.000000   120.000000           5.000000    5.000000
#
#             LOR         CGPA    Research  Chance of Admit
# count  500.00000  500.000000  500.000000         500.00000
# mean     3.48400    8.576440    0.560000           0.72174
# std      0.92545    0.604813    0.496884           0.14114
# min      1.00000    6.800000    0.000000           0.34000
# ...

# %%
admission_predict.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Serial No.         500 non-null    int64
#  1   GRE Score          500 non-null    int64
#  2   TOEFL Score        500 non-null    int64
#  3   University Rating  500 non-null    int64
#  4   SOP                500 non-null    float64
#  5   LOR                500 non-null    float64
#  6   CGPA               500 non-null    float64
#  7   Research           500 non-null    int64
#  8   Chance of Admit    500 non-null    float64
# dtypes: float64(4), int64(5)
# memory usage: 35.3 KB

# %%
# x_feature - GRE Score
# y_feature - Chance of Admit
x = admission_predict['GRE Score'].values
y = admission_predict['Chance of Admit '].values
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.7,test_size=0.3,random_state=100)
x_train= x_train.reshape(-1, 1)
y_train= y_train.reshape(-1, 1)
x_test = x_test.reshape(-1, 1)
y_train = y_train.reshape(-1,1)
print(f'x_train shape {x_train.shape}')
print(f'y_train shape {y_train.shape}')
print(f'x_test shape {x_test.shape}')
print(f'y_test shape {y_test.shape}')
# Out:
# x_train shape (350, 1)
# y_train shape (350, 1)
# x_test shape (150, 1)
# y_test shape (150,)

# %%
plt.scatter(x_train,y_train,color='cyan')
plt.xlabel('GRE Score')
plt.ylabel('Chance of Admit')
plt.show()

# %%
lr=LinearRegression()
lr.fit(x_train,y_train)
y_predict = lr.predict(x_test)
print(f"Train accuracy {round(lr.score(x_train,y_train)*100,2)} %")
print(f"Test accuracy {round(lr.score(x_test,y_test)*100,2)} %")
# Out:
# Train accuracy 63.76 %
# Test accuracy 69.75 %

# %%
plt.scatter(x_train,y_train,color='cyan')
plt.plot(x_test,y_predict)
plt.xlabel('GRE Score')
plt.ylabel('Chance of Admit')
plt.show()

# %% [markdown]
# ## Conclusion:
#
# * Train accuracy 63.76 % Test accuracy 69.75 %
# * Relation between GRE Score and Chance of Admit is positive Linear Regression
